# %%
import pandas as pd

# %%
nifty = pd.read_csv(r"C:\Users\Jayanth.Appalla\Desktop\pandas\niftydata.csv")

# %%
nifty.head() #without header
# Out:
#    9/17/2007  4494.649902
# 0  9/18/2007  4546.200195
# 1  9/19/2007  4732.350098
# 2  9/20/2007  4747.549805
# 3  9/21/2007  4837.549805
# 4  9/24/2007  4932.200195

# %%
nifty = pd.read_csv(r"C:\Users\Jayanth.Appalla\Desktop\pandas\niftydata.csv",header=None)
nifty.head()
# Out:
#            0            1
# 0  9/17/2007  4494.649902
# 1  9/18/2007  4546.200195
# 2  9/19/2007  4732.350098
# 3  9/20/2007  4747.549805
# 4  9/21/2007  4837.549805

# %%
nifty = pd.read_csv(r"C:\Users\Jayanth.Appalla\Desktop\pandas\niftydata.csv",header=None,nrows=20)
nifty
# Out:
#              0            1
# 0    9/17/2007  4494.649902
# 1    9/18/2007  4546.200195
# 2    9/19/2007  4732.350098
# 3    9/20/2007  4747.549805
# 4    9/21/2007  4837.549805
# 5    9/24/2007  4932.200195
# 6    9/25/2007  4938.850098
# 7    9/26/2007  4940.500000
# 8    9/27/2007  5000.549805
# 9    9/28/2007  5021.350098
# 10   10/1/2007  5068.950195
# 11   10/3/2007  5210.799805
# 12   10/4/2007  5208.649902
# 13   10/5/2007  5185.850098
# 14   10/8/2007  5085.100098
# 15   10/9/2007  5327.250000
# 16  10/10/2007  5441.450195
# 17  10/11/2007  5524.850098
# 18  10/12/2007  5428.250000
# 19  10/15/2007  5670.399902

# %%
col_names=['trade_date','closing_price']
nifty = pd.read_csv(r"C:\Users\Jayanth.Appalla\Desktop\pandas\niftydata.csv",header=None,names=col_names) #use column names 
nifty
# Out:
#       trade_date  closing_price
# 0      9/17/2007    4494.649902
# 1      9/18/2007    4546.200195
# 2      9/19/2007    4732.350098
# 3      9/20/2007    4747.549805
# 4      9/21/2007    4837.549805
# ...          ...            ...
# 2514  11/23/2017   10348.750000
# 2515  11/24/2017   10389.700200
# 2516  11/27/2017   10399.549810
# 2517  11/28/2017   10370.250000
# 2518  11/29/2017   10361.300000
#
# [2519 rows x 2 columns]

# %%
col_names=['trade_date','closing_price']
path=r"C:\Users\Jayanth.Appalla\Desktop\pandas\niftydata.csv"
nifty = pd.read_csv(path,header=None,names=col_names)
nifty
# Out:
#       trade_date  closing_price
# 0      9/17/2007    4494.649902
# 1      9/18/2007    4546.200195
# 2      9/19/2007    4732.350098
# 3      9/20/2007    4747.549805
# 4      9/21/2007    4837.549805
# ...          ...            ...
# 2514  11/23/2017   10348.750000
# 2515  11/24/2017   10389.700200
# 2516  11/27/2017   10399.549810
# 2517  11/28/2017   10370.250000
# 2518  11/29/2017   10361.300000
#
# [2519 rows x 2 columns]

# %%
nifty.describe() # statistics about the data
# Out:
#        closing_price
# count    2495.000000
# mean     6331.771002
# std      1785.887216
# min      2524.199951
# 25%      5121.125000
# 50%      5860.950195
# 75%      7959.724853
# max     10452.500000

# %%
nifty.describe(include = 'all') # statistics about the data
# Out:
#        trade_date  closing_price
# count        2519    2495.000000
# unique       2519            NaN
# top     6/15/2016            NaN
# freq            1            NaN
# mean          NaN    6331.771002
# std           NaN    1785.887216
# min           NaN    2524.199951
# 25%           NaN    5121.125000
# 50%           NaN    5860.950195
# 75%           NaN    7959.724853
# max           NaN   10452.500000

# %%
nifty.describe(include = ['object'])
nifty.describe(include = ['float'])
# Out:
#        closing_price
# count    2495.000000
# mean     6331.771002
# std      1785.887216
# min      2524.199951
# 25%      5121.125000
# 50%      5860.950195
# 75%      7959.724853
# max     10452.500000

# %%
path=r'C:\Users\Jayanth.Appalla\Desktop\pandas\Sample - Superstore Sales.xls'
orders=pd.read_excel(path,0)

# %%
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.Sales.sort_values() # sort in ascending order
# Out:
# 888         2.24
# 3552        3.20
# 3262        3.23
# 6986        3.41
# 1313        3.42
#           ...
# 4628    29884.60
# 2025    33367.85
# 4263    41343.21
# 451     45923.76
# 4189    89061.05
# Name: Sales, Length: 8390, dtype: float64

# %%
orders.Sales.sort_values(ascending=False).head() # first five in descending order, sales column has no space so we can access it using dot(.) notation
# Out:
# 4189    89061.05
# 451     45923.76
# 4263    41343.21
# 2025    33367.85
# 4628    29884.60
# Name: Sales, dtype: float64

# %%
orders['Sales'].sort_values(ascending=False).head()
# Out:
# 4189    89061.05
# 451     45923.76
# 4263    41343.21
# 2025    33367.85
# 4628    29884.60
# Name: Sales, dtype: float64

# %%
orders['Order Date'].sort_values()
# Out:
# 1913   2009-01-01
# 4030   2009-01-01
# 5272   2009-01-02
# 1278   2009-01-02
# 5271   2009-01-02
#           ...
# 6914   2012-12-30
# 7140   2012-12-30
# 7141   2012-12-30
# 6711   2012-12-30
# 6915   2012-12-30
# Name: Order Date, Length: 8390, dtype: datetime64[ns]

# %%
orders.sort_values('Sales',ascending=False).head() #entire dataset sorted as per sales
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766 2009-03-21         Medium              13  89061.05
# 451      452      3073 2009-01-07         Medium               7  45923.76
# 4263    4264     30343 2012-05-21       Critical               8  41343.21
# 2025    2026     14435 2012-12-01  Not Specified               9  33367.85
# 4628    4629     32932 2010-01-09            Low              49  29884.60
#
#       Discount    Ship Mode    Profit  Unit Price  ...    Customer Name  \
# 4189      0.00  Regular Air  27220.69     6783.02  ...       Emily Phan
# 451       0.07  Regular Air    102.61     6783.02  ...  Jasper Cacioppo
# 4263      0.09  Regular Air   3852.19     6783.02  ...   Craig Carreira
# 2025      0.01  Regular Air   3992.52     3499.99  ...      Dennis Kane
# 4628      0.05  Regular Air  12748.86      599.99  ...   Karen Carlisle
#
#               Province    Region Customer Segment Product Category  \
# ...

# %%
orders.sort_values('Sales').head()# in ascending order
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity  Sales  \
# 888      889      6374 2011-08-07       Critical               1   2.24
# 3552    3553     25318 2011-11-19       Critical               1   3.20
# 3262    3263     23361 2010-07-03       Critical               2   3.23
# 6986    6987     49925 2010-01-22           High               1   3.41
# 1313    1314      9635 2009-04-13       Critical               1   3.42
#
#       Discount    Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 888       0.01  Regular Air -1.9700        1.48  ...     Ricardo Emerson
# 3552      0.09  Regular Air -3.1625        1.88  ...            Ken Dana
# 3262      0.06  Regular Air -2.7300        1.26  ...  Benjamin Patterson
# 6986      0.06  Regular Air -1.7800        2.88  ...           Adam Hart
# 1313      0.05  Regular Air -2.9095        1.88  ...         Andy Reiter
#
#               Province  Region Customer Segment Product Category  \
# ...

# %%
orders.sort_values(['Sales','Discount'],ascending=False).head()
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766 2009-03-21         Medium              13  89061.05
# 451      452      3073 2009-01-07         Medium               7  45923.76
# 4263    4264     30343 2012-05-21       Critical               8  41343.21
# 2025    2026     14435 2012-12-01  Not Specified               9  33367.85
# 4628    4629     32932 2010-01-09            Low              49  29884.60
#
#       Discount    Ship Mode    Profit  Unit Price  ...    Customer Name  \
# 4189      0.00  Regular Air  27220.69     6783.02  ...       Emily Phan
# 451       0.07  Regular Air    102.61     6783.02  ...  Jasper Cacioppo
# 4263      0.09  Regular Air   3852.19     6783.02  ...   Craig Carreira
# 2025      0.01  Regular Air   3992.52     3499.99  ...      Dennis Kane
# 4628      0.05  Regular Air  12748.86      599.99  ...   Karen Carlisle
#
#               Province    Region Customer Segment Product Category  \
# ...

# %%
help(orders.sort_values) #documentation of sort_values
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False) method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#             by : str or list of str
#                 Name or list of names to sort by.
#
#                 - if `axis` is 0 or `'index'` then `by` may contain index
#                   levels and/or column labels.
#                 - if `axis` is 1 or `'columns'` then `by` may contain column
#                   levels and/or index labels.
#
#                 .. versionchanged:: 0.23.0
#
#                    Allow specifying index or column level names.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
# ...

# %%
orders.isnull().sum() # number of null values in each column
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# dtype: int64

# %%
orders.isnull().sum().sum() # total number of null valued cells
# Out:
# 63

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.sort_values(['Sales','Discount'],ascending=False)# sorting by multiple columns
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766 2009-03-21         Medium              13  89061.05
# 451      452      3073 2009-01-07         Medium               7  45923.76
# 4263    4264     30343 2012-05-21       Critical               8  41343.21
# 2025    2026     14435 2012-12-01  Not Specified               9  33367.85
# 4628    4629     32932 2010-01-09            Low              49  29884.60
# ...      ...       ...        ...            ...             ...       ...
# 1313    1314      9635 2009-04-13       Critical               1      3.42
# 6986    6987     49925 2010-01-22           High               1      3.41
# 3262    3263     23361 2010-07-03       Critical               2      3.23
# 3552    3553     25318 2011-11-19       Critical               1      3.20
# 888      889      6374 2011-08-07       Critical               1      2.24
#
# ...

# %%
orders[orders['Sales']<=500] #filtering by sales
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0          1         3 2010-10-13            Low               6  261.5400
# 1          2         6 2012-02-20  Not Specified               2    6.9300
# 4          5        32 2011-07-15           High              23  160.2335
# 5          6        32 2011-07-15           High              15  140.5600
# 6          7        35 2011-10-22  Not Specified              30  288.5600
# ...      ...       ...        ...            ...             ...       ...
# 8384    8385     59906 2010-05-20           High              32  284.9200
# 8386    8387     59909 2012-08-05            Low              46  411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1   10.5900
# 8388    8389     59937 2009-12-28           High               7  235.9800
# 8389    8390     59939 2010-09-01         Medium              42  130.9600
#
# ...

# %%
orders[orders['Order Priority']=='Low']
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity    Sales  \
# 0          1         3 2010-10-13            Low               6   261.54
# 10        11        66 2009-01-19            Low              41   108.15
# 13        14        70 2010-12-17            Low              48    90.05
# 14        15        70 2010-12-17            Low              46  7804.53
# 17        18       129 2012-11-18            Low               4    32.72
# ...      ...       ...        ...            ...             ...      ...
# 8370    8371     59783 2010-08-19            Low              36    77.43
# 8376    8377     59845 2009-12-22            Low              42   200.10
# 8377    8378     59845 2009-12-22            Low              28   120.54
# 8385    8386     59909 2012-08-05            Low              11  1255.48
# 8386    8387     59909 2012-08-05            Low              46   411.56
#
#       Discount       Ship Mode     Profit  Unit Price  ...  \
# ...

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)
#     Read an Excel file into a pandas DataFrame.
#
#     Supports `xls`, `xlsx`, `xlsm`, `xlsb`, and `odf` file extensions
#     read from a local filesystem or URL. Supports an option to read
#     a single sheet or a list of sheets.
#
#     Parameters
#     ----------
#     io : str, bytes, ExcelFile, xlrd.Book, path object, or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, and file. For file URLs, a host is
# ...

# %%
orders[orders['Order Priority']!='Low']
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# 5          6        32 2011-07-15           High              15   140.5600
# ...      ...       ...        ...            ...             ...        ...
# 8383    8384     59905 2012-04-14           High               5    26.5000
# 8384    8385     59906 2010-05-20           High              32   284.9200
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
orders[(orders['Order Priority']=='Low') & (orders['Province']=='Alberta')] # multiple filtering
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 10        11        66 2009-01-19            Low              41   108.150
# 64        65       384 2012-03-02            Low              50  7666.040
# 128      129       832 2012-04-18            Low               7    53.460
# 189      190      1280 2010-01-10            Low              40   827.270
# 436      437      2915 2009-03-30            Low              41   231.260
# ...      ...       ...        ...            ...             ...       ...
# 8037    8038     57412 2009-07-13            Low              34   223.499
# 8240    8241     58914 2009-04-09            Low              46    99.940
# 8241    8242     58914 2009-04-09            Low              11    18.700
# 8337    8338     59586 2012-03-07            Low              25   167.230
# 8355    8356     59686 2011-03-08            Low              41   243.370
#
# ...

# %%
orders[orders['Province']== 'Alberta']
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# 8          9        36 2011-11-02       Critical              46  2484.7455
# ...      ...       ...        ...            ...             ...        ...
# 8304    8305     59329 2012-12-04       Critical              25   165.6200
# 8305    8306     59329 2012-12-04       Critical              41   214.2300
# 8306    8307     59329 2012-12-04       Critical              41   214.1900
# 8337    8338     59586 2012-03-07            Low              25   167.2300
# 8355    8356     59686 2011-03-08            Low              41   243.3700
#
# ...

# %%
orders[(orders['Order Priority']=='Low') | (orders['Province']=='Alberta')]
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8370    8371     59783 2010-08-19            Low              36    77.4300
# 8376    8377     59845 2009-12-22            Low              42   200.1000
# 8377    8378     59845 2009-12-22            Low              28   120.5400
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
#
# ...

# %%
orders[orders['Province'].isin(['Alberta','Nunavut'])] # isin method to evaluate multiple conditions for OR.
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8304    8305     59329 2012-12-04       Critical              25   165.6200
# 8305    8306     59329 2012-12-04       Critical              41   214.2300
# 8306    8307     59329 2012-12-04       Critical              41   214.1900
# 8337    8338     59586 2012-03-07            Low              25   167.2300
# 8355    8356     59686 2011-03-08            Low              41   243.3700
#
# ...

# %% [markdown]
# # Deleting Rows and Columns

# %%
orders.drop('Row ID', axis=1, inplace=False) # inplace= true means the code output will affect the orders dataframe as well, with inplace=false we do not make any changes to the dataframe.
# Out:
#       Order ID Order Date Order Priority  Order Quantity      Sales  Discount  \
# 0            3 2010-10-13            Low               6   261.5400      0.04
# 1            6 2012-02-20  Not Specified               2     6.9300      0.01
# 2           32 2011-07-15           High              26  2808.0800      0.07
# 3           32 2011-07-15           High              24  1761.4000      0.09
# 4           32 2011-07-15           High              23   160.2335      0.04
# ...        ...        ...            ...             ...        ...       ...
# 8385     59909 2012-08-05            Low              11  1255.4800      0.06
# 8386     59909 2012-08-05            Low              46   411.5600      0.09
# 8387     59911 2011-12-18  Not Specified               1    10.5900      0.10
# 8388     59937 2009-12-28           High               7   235.9800      0.02
# 8389     59939 2010-09-01         Medium              42   130.9600      0.05
#
# ...

# %%
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
orders.drop(['Order Date','Order Priority'],axis=1,inplace=False)
# Out:
#       Row ID  Order ID  Order Quantity      Sales  Discount       Ship Mode  \
# 0          1         3               6   261.5400      0.04     Regular Air
# 1          2         6               2     6.9300      0.01     Regular Air
# 2          3        32              26  2808.0800      0.07     Regular Air
# 3          4        32              24  1761.4000      0.09  Delivery Truck
# 4          5        32              23   160.2335      0.04     Regular Air
# ...      ...       ...             ...        ...       ...             ...
# 8385    8386     59909              11  1255.4800      0.06  Delivery Truck
# 8386    8387     59909              46   411.5600      0.09     Express Air
# 8387    8388     59911               1    10.5900      0.10     Regular Air
# 8388    8389     59937               7   235.9800      0.02     Regular Air
# 8389    8390     59939              42   130.9600      0.05     Regular Air
#
# ...

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.drop([2,3,4],axis=0,inplace=False) #delete rows
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0          1         3 2010-10-13            Low               6   261.540
# 1          2         6 2012-02-20  Not Specified               2     6.930
# 5          6        32 2011-07-15           High              15   140.560
# 6          7        35 2011-10-22  Not Specified              30   288.560
# 7          8        35 2011-10-22  Not Specified              14  1892.848
# ...      ...       ...        ...            ...             ...       ...
# 8385    8386     59909 2012-08-05            Low              11  1255.480
# 8386    8387     59909 2012-08-05            Low              46   411.560
# 8387    8388     59911 2011-12-18  Not Specified               1    10.590
# 8388    8389     59937 2009-12-28           High               7   235.980
# 8389    8390     59939 2010-09-01         Medium              42   130.960
#
#       Discount       Ship Mode    Profit  Unit Price  ...  \
# ...

# %%
orders.iloc[:,2:5]
# Out:
#      Order Date Order Priority  Order Quantity
# 0    2010-10-13            Low               6
# 1    2012-02-20  Not Specified               2
# 2    2011-07-15           High              26
# 3    2011-07-15           High              24
# 4    2011-07-15           High              23
# ...         ...            ...             ...
# 8385 2012-08-05            Low              11
# 8386 2012-08-05            Low              46
# 8387 2011-12-18  Not Specified               1
# 8388 2009-12-28           High               7
# 8389 2010-09-01         Medium              42
#
# [8390 rows x 3 columns]

# %%
orders.drop(orders.iloc[:,0:3],axis=1,inplace=False) # delete columns by indexing with integers
# Out:
#      Order Priority  Order Quantity      Sales  Discount       Ship Mode  \
# 0               Low               6   261.5400      0.04     Regular Air
# 1     Not Specified               2     6.9300      0.01     Regular Air
# 2              High              26  2808.0800      0.07     Regular Air
# 3              High              24  1761.4000      0.09  Delivery Truck
# 4              High              23   160.2335      0.04     Regular Air
# ...             ...             ...        ...       ...             ...
# 8385            Low              11  1255.4800      0.06  Delivery Truck
# 8386            Low              46   411.5600      0.09     Express Air
# 8387  Not Specified               1    10.5900      0.10     Regular Air
# 8388           High               7   235.9800      0.02     Regular Air
# 8389         Medium              42   130.9600      0.05     Regular Air
#
#          Profit  Unit Price  Shipping Cost           Customer Name  \
# ...

# %% [markdown]
# # Working with DataFrames

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
orders.columns[0:3]
# Out:
# Index(['Row ID', 'Order ID', 'Order Date'], dtype='object')

# %%
orders_subset = DataFrame(orders,columns=orders.columns[:7]) # selecting only few columns.
orders_subset.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount
# 0      0.04
# 1      0.01
# 2      0.07
# 3      0.09
# 4      0.04

# %%
orders_subset['Sales'] # selecting a single column
# Out:
# 0        261.5400
# 1          6.9300
# 2       2808.0800
# 3       1761.4000
# 4        160.2335
#           ...
# 8385    1255.4800
# 8386     411.5600
# 8387      10.5900
# 8388     235.9800
# 8389     130.9600
# Name: Sales, Length: 8390, dtype: float64

# %%
del orders_subset['Discount'] # deleting discount column

# %%
orders_subset
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# [8390 rows x 6 columns]

# %%
orders_subset.drop(['Sales'],axis=1)
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity
# 0          1         3 2010-10-13            Low               6
# 1          2         6 2012-02-20  Not Specified               2
# 2          3        32 2011-07-15           High              26
# 3          4        32 2011-07-15           High              24
# 4          5        32 2011-07-15           High              23
# ...      ...       ...        ...            ...             ...
# 8385    8386     59909 2012-08-05            Low              11
# 8386    8387     59909 2012-08-05            Low              46
# 8387    8388     59911 2011-12-18  Not Specified               1
# 8388    8389     59937 2009-12-28           High               7
# 8389    8390     59939 2010-09-01         Medium              42
#
# [8390 rows x 5 columns]

# %%
orders_subset
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# [8390 rows x 6 columns]

# %% [markdown]
# # Working with Series

# %%
import pandas as pd
from pandas import Series

# %%
ser=Series([1,2,3,4,5])

# %%
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser[2]
# Out:
# 3

# %%
ser.index # gives information about indexing
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser=Series([1,2,3,4,5,6],index=['a','b','c','d','e','f']) # indexing with a,b,c,d,e,f

# %%
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
ser[3]
# Out:
# 4

# %%
ser['d']
# Out:
# 4

# %%
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
orders['Order Priority'] #series
# Out:
# 0                 Low
# 1       Not Specified
# 2                High
# 3                High
# 4                High
#             ...
# 8385              Low
# 8386              Low
# 8387    Not Specified
# 8388             High
# 8389           Medium
# Name: Order Priority, Length: 8390, dtype: object

# %%
orders.Profit # series
# Out:
# 0       -213.2500
# 1         -4.6400
# 2       1054.8200
# 3      -1748.5600
# 4        -85.1290
#           ...
# 8385    -292.6506
# 8386    -188.0200
# 8387      -4.3100
# 8388     -32.2800
# 8389     -66.7400
# Name: Profit, Length: 8390, dtype: float64

# %%
orders.Profit + orders.Sales # adding series and displaying together
# Out:
# 0         48.2900
# 1          2.2900
# 2       3862.9000
# 3         12.8400
# 4         75.1045
#           ...
# 8385     962.8294
# 8386     223.5400
# 8387       6.2800
# 8388     203.7000
# 8389      64.2200
# Length: 8390, dtype: float64

# %%
orders['Ship Mode'] + '            '+orders['Province']
# Out:
# 0           Regular Air            Nunavut
# 1           Regular Air            Alberta
# 2           Regular Air            Alberta
# 3        Delivery Truck            Alberta
# 4           Regular Air            Alberta
#                        ...
# 8385     Delivery Truck            Ontario
# 8386        Express Air            Ontario
# 8387    Regular Air            Saskachewan
# 8388         Regular Air            Quebec
# 8389    Regular Air            Saskachewan
# Length: 8390, dtype: object

# %%
orders.size # total number of cells in the dataset.
# Out:
# 176190

# %%
orders.Sales.size # size of sales series
# Out:
# 8390

# %% [markdown]
# # Reading data in excel using different options

# %%
path=r'C:\Users\Jayanth.Appalla\Desktop\pandas\Sample - Superstore Sales.xls'
orders=pd.read_excel(path)
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
xl_file=pd.ExcelFile(path) # read in the entire workbook
orders=xl_file.parse('Orders') # read in sheet by name

# %%
xl_file

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %% [markdown]
# # Answering the questions with data Analysis

# %%
import pandas as pd

# %%
orders=pd.read_excel(path,0)
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8386    8387     59909 2012-08-05            Low              46   411.5600
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.groupby('Customer Segment').Sales.sum()
# Out:
# Customer Segment
# Consumer          3.063611e+06
# Corporate         5.498190e+06
# Home Office       3.562063e+06
# Small Business    2.772298e+06
# Name: Sales, dtype: float64

# %%
orders.groupby('Province').Profit.sum() # groupby groups a particular category , that is assembles all unique values of a column.
# Out:
# Province
# Alberta                  152215.150600
# British Columbia         145114.185430
# Manitoba                 136308.627900
# New Brunswick            115351.913200
# Newfoundland               6885.144914
# Northwest Territories    100653.051900
# Nova Scotia               85361.822406
# Nunavut                    2841.117000
# Ontario                  346868.581175
# Prince Edward Island      31361.732410
# Quebec                   140426.594746
# Saskachewan              181859.099000
# Yukon                     73849.245400
# Name: Profit, dtype: float64

# %%
orders['Product Name'].value_counts()
# Out:
# Global High-Back Leather Tilter, Burgundy                            24
# Master Giant Foot® Doorstop, Safety Yellow                           22
# Fiskars® Softgrip Scissors                                           22
# Bevis 36 x 72 Conference Tables                                      22
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables    22
#                                                                      ..
# Hewlett Packard 610 Color Digital Copier / Printer                    1
# Xerox 209                                                             1
# SAFCO Boltless Steel Shelving                                         1
# DMI Arturo Collection Mission-style Design Wood Chair                 1
# Accessory1                                                            1
# Name: Product Name, Length: 1263, dtype: int64

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
orders.count()
# Out:
# Row ID                  8390
# Order ID                8390
# Order Date              8390
# Order Priority          8390
# Order Quantity          8390
# Sales                   8390
# Discount                8390
# Ship Mode               8390
# Profit                  8390
# Unit Price              8390
# Shipping Cost           8390
# Customer Name           8390
# Province                8390
# Region                  8390
# Customer Segment        8390
# Product Category        8390
# Product Sub-Category    8390
# Product Name            8390
# Product Container       8390
# Product Base Margin     8327
# Ship Date               8390
# dtype: int64

# %%
orders.shape #number of rows, columns
# Out:
# (8390, 21)

# %%
orders.shape[0]# number of rows
# Out:
# 8390

# %%
orders['Province'].nunique() # number of unique values in the column
# Out:
# 13

# %%
orders.groupby('Product Name').Profit.sum().nlargest(6)
# Out:
# Product Name
# Global Troy™ Executive Leather Low-Back Tilter                 79284.780
# Hewlett Packard LaserJet 3310 Copier                           73299.600
# Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers    55281.390
# GBC DocuBind 200 Manual Binding Machine                        50462.515
# Canon PC940 Copier                                             47705.836
# Fellowes PB300 Plastic Comb Binding Machine                    45927.856
# Name: Profit, dtype: float64

# %%
orders.groupby('Product Name').Profit.sum().nsmallest(6)
# Out:
# Product Name
# Okidata Pacemark 4410N Wide Format Dot Matrix Printer   -43949.3724
# Canon imageCLASS 2200 Advanced Copier                   -31885.6770
# Global High-Back Leather Tilter, Burgundy               -30518.9000
# Epson DFX-8500 Dot Matrix Printer                       -29400.3450
# Hoover Portapower™ Portable Vacuum                      -21088.4800
# Polycom ViewStation™ ISDN Videoconferencing Unit        -17771.2668
# Name: Profit, dtype: float64

# %% [markdown]
# # Grouping data using group by clause

# %%
import pandas as pd

# %%
orders=pd.read_excel(path)
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.groupby('Order Priority').Sales.sum()
# Out:
# Order Priority
# Critical         2.722810e+06
# High             3.266644e+06
# Low              3.266608e+06
# Medium           2.861738e+06
# Not Specified    2.778363e+06
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.mean()
# Out:
# Order Priority
# Critical         1697.512545
# High             1849.741575
# Low              1901.401445
# Medium           1755.667275
# Not Specified    1661.700536
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.max()
# Out:
# Order Priority
# Critical         41343.21
# High             28664.52
# Low              29884.60
# Medium           89061.05
# Not Specified    33367.85
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.min()
# Out:
# Order Priority
# Critical         2.24
# High             3.41
# Low              3.63
# Medium           4.94
# Not Specified    3.85
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.agg(['sum','mean','max','min'])
# Out:
#                          sum         mean       max   min
# Order Priority
# Critical        2.722810e+06  1697.512545  41343.21  2.24
# High            3.266644e+06  1849.741575  28664.52  3.41
# Low             3.266608e+06  1901.401445  29884.60  3.63
# Medium          2.861738e+06  1755.667275  89061.05  4.94
# Not Specified   2.778363e+06  1661.700536  33367.85  3.85
